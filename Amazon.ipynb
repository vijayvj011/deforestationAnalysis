# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rawdf= pd.read_csv('def_area_2004_2019.csv')
rawdf
# Out:
#     Ano/Estados   AC    AM   AP    MA     MT    PA    RO   RR   TO  AMZ LEGAL
# 0          2004  728  1232   46   755  11814  8870  3858  311  158      27772
# 1          2005  592   775   33   922   7145  5899  3244  133  271      19014
# 2          2006  398   788   30   674   4333  5659  2049  231  124      14286
# 3          2007  184   610   39   631   2678  5526  1611  309   63      11651
# 4          2008  254   604  100  1271   3258  5607  1136  574  107      12911
# 5          2009  167   405   70   828   1049  4281   482  121   61       7464
# 6          2010  259   595   53   712    871  3770   435  256   49       7000
# 7          2011  280   502   66   396   1120  3008   865  141   40       6418
# 8          2012  305   523   27   269    757  1741   773  124   52       4571
# 9          2013  221   583   23   403   1139  2346   932  170   74       5891
# 10         2014  309   500   31   257   1075  1887   684  219   50       5012
# 11         2015  264   712   25   209   1601  2153  1030  156   57       6207
# 12         2016  372  1129   17   258   1489  2992  1376  202   58       7893
# 13         2017  257  1001   24   265   1561  2433  1243  132   31       6947
# 14         2018  444  1045   24   253   1490  2744  1316  195   25       7536
# 15         2019  688  1421    8   215   1685  3862  1245  617   21       9762

# %%
rawdf.rename({
    'Ano/Estados':'Year',
    'AC':'Acre',
    'AM': 'Amazonas',
    'AP': 'Amapa',
    'MA':'Maranhao',
    'MT':'Mato Grosso',
    'PA':'Para',
    'RO':'Rondonia',
    'RR':'Roraima',
    'TO':'Tocantins',
    'AMZ LEGAL':'Total'
}, axis=1, inplace=True)
rawdf
# Out:
#     Year  Acre  Amazonas  Amapa  Maranhao  Mato Grosso  Para  Rondonia  \
# 0   2004   728      1232     46       755        11814  8870      3858
# 1   2005   592       775     33       922         7145  5899      3244
# 2   2006   398       788     30       674         4333  5659      2049
# 3   2007   184       610     39       631         2678  5526      1611
# 4   2008   254       604    100      1271         3258  5607      1136
# 5   2009   167       405     70       828         1049  4281       482
# 6   2010   259       595     53       712          871  3770       435
# 7   2011   280       502     66       396         1120  3008       865
# 8   2012   305       523     27       269          757  1741       773
# 9   2013   221       583     23       403         1139  2346       932
# 10  2014   309       500     31       257         1075  1887       684
# 11  2015   264       712     25       209         1601  2153      1030
# 12  2016   372      1129     17       258         1489  2992      1376
# 13  2017   257      1001     24       265         1561  2433      1243
# 14  2018   444      1045     24       253         1490  2744      1316
# 15  2019   688      1421      8       215         1685  3862      1245
#
#     Roraima  Tocantins  Total
# 0       311        158  27772
# 1       133        271  19014
# 2       231        124  14286
# 3       309         63  11651
# 4       574        107  12911
# 5       121         61   7464
# 6       256         49   7000
# 7       141         40   6418
# 8       124         52   4571
# 9       170         74   5891
# 10      219         50   5012
# 11      156         57   6207
# 12      202         58   7893
# 13      132         31   6947
# 14      195         25   7536
# 15      617         21   9762

# %%
rawdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         16 non-null     int64
#  1   Acre         16 non-null     int64
#  2   Amazonas     16 non-null     int64
#  3   Amapa        16 non-null     int64
#  4   Maranhao     16 non-null     int64
#  5   Mato Grosso  16 non-null     int64
#  6   Para         16 non-null     int64
#  7   Rondonia     16 non-null     int64
#  8   Roraima      16 non-null     int64
#  9   Tocantins    16 non-null     int64
#  10  Total        16 non-null     int64
# dtypes: int64(11)
# memory usage: 1.5 KB

# %%
rawdf.describe()
# Out:
#               Year        Acre     Amazonas       Amapa     Maranhao  \
# count    16.000000   16.000000    16.000000   16.000000    16.000000
# mean   2011.500000  357.625000   776.562500   38.500000   519.875000
# std       4.760952  172.476037   300.648625   23.557023   316.705305
# min    2004.000000  167.000000   405.000000    8.000000   209.000000
# 25%    2007.750000  256.250000   568.000000   24.000000   257.750000
# 50%    2011.500000  292.500000   661.000000   30.500000   399.500000
# 75%    2015.250000  409.500000  1012.000000   47.750000   722.750000
# max    2019.000000  728.000000  1421.000000  100.000000  1271.000000
#
#         Mato Grosso         Para     Rondonia     Roraima   Tocantins  \
# count     16.000000    16.000000    16.000000   16.000000   16.000000
# mean    2691.562500  3923.625000  1392.437500  243.187500   77.562500
# std     2940.367595  1945.802487   943.567413  150.567468   63.238141
# min      757.000000  1741.000000   435.000000  121.000000   21.000000
# 25%     1108.750000  2411.250000   842.000000  139.000000   46.750000
# 50%     1525.500000  3389.000000  1189.500000  198.500000   57.500000
# 75%     2823.000000  5546.250000  1434.750000  269.250000   82.250000
# max    11814.000000  8870.000000  3858.000000  617.000000  271.000000
#
#               Total
# count     16.000000
# mean   10020.937500
# std     6112.467134
# min     4571.000000
# 25%     6365.250000
# 50%     7500.000000
# 75%    11966.000000
# max    27772.000000

# %%
plt.figure(figsize=(15,8))
sns.set_style("whitegrid")
plt.bar(rawdf['Year'], rawdf['Total'], color='red', align= 'center')
plt.title('Total Deforested Area By Year From 2004-2019', fontsize=20)
plt.xlabel('Year', fontsize= 14)
plt.ylabel('Deforestated Area in Km2', fontsize= 14)
# Out:
# Text(0, 0.5, 'Deforestated Area in Km2')

# %%
PercentofDeforestation2019= (rawdf['Total'][15].sum())/rawdf['Total'].sum()
PercentofDeforestation2019
# Out:
# 0.060885021985218446

# %%
states=rawdf.drop(["Year", "Total"], axis=1)
states
# Out:
#     Acre  Amazonas  Amapa  Maranhao  Mato Grosso  Para  Rondonia  Roraima  \
# 0    728      1232     46       755        11814  8870      3858      311
# 1    592       775     33       922         7145  5899      3244      133
# 2    398       788     30       674         4333  5659      2049      231
# 3    184       610     39       631         2678  5526      1611      309
# 4    254       604    100      1271         3258  5607      1136      574
# 5    167       405     70       828         1049  4281       482      121
# 6    259       595     53       712          871  3770       435      256
# 7    280       502     66       396         1120  3008       865      141
# 8    305       523     27       269          757  1741       773      124
# 9    221       583     23       403         1139  2346       932      170
# 10   309       500     31       257         1075  1887       684      219
# 11   264       712     25       209         1601  2153      1030      156
# 12   372      1129     17       258         1489  2992      1376      202
# 13   257      1001     24       265         1561  2433      1243      132
# 14   444      1045     24       253         1490  2744      1316      195
# 15   688      1421      8       215         1685  3862      1245      617
#
#     Tocantins
# 0         158
# 1         271
# 2         124
# 3          63
# 4         107
# 5          61
# 6          49
# 7          40
# 8          52
# 9          74
# 10         50
# 11         57
# 12         58
# 13         31
# 14         25
# 15         21

# %%
plt.figure(figsize=(15,8))
plt.bar(states.columns, states.sum(), color='brown', align= 'center')
plt.title('Total Deforested Area By State From 2004-2019', fontsize=20)
plt.xlabel('State', fontsize= 14)
plt.ylabel('Deforestated Area in Km2', fontsize= 14)
# Out:
# Text(0, 0.5, 'Deforestated Area in Km2')

# %%
fig, ax = plt.subplots(figsize=(15,8))
#graph inspired from https://www.kaggle.com/sbengali/brazilian-amazon-rainforest-degradation-analysis
states1 = ['Acre', 'Amazonas', 'Amapa', 'Maranhao', 'Mato Grosso', 'Para', 'Rondonia', 'Roraima', 'Tocantins', 'Total']
rawdf.plot(x='Year', y= rawdf.columns[1:11], label=states1 , colormap='tab10', linewidth=2, ax=ax)
plt.title('Total Deforested Area By Year By State and Total From 2004-2019', fontsize=20)
plt.xlabel('Year', fontsize= 14)
plt.ylabel('Deforestated Area in Km2', fontsize= 14)
# Out:
# Text(0, 0.5, 'Deforestated Area in Km2')

# %%
fig, ax = plt.subplots(5, 2, figsize=(15,10))
plt.subplots_adjust(wspace=0.3, hspace=0.7)
plt.suptitle('Deforested Amazon Area in each State and Total Deforestation from 2004-2019', fontsize=16)
col_names = rawdf.columns[1:11]
for i in range(5):
    for j in range(2):
        #Creates subplots of the different states and total deforestation
        col = col_names[i*2+j]
        ax[i,j].plot(rawdf['Year'], rawdf[col], linewidth=2, color='darkgreen')
        ax[i,j].set_ylabel('Area in km2', fontsize=12)
        ax[i,j].set_xlabel('Year', fontsize=12)
        ax[i,j].set_title(states1[i*2+j], fontsize=14)

# %%
weatherdf=pd.read_csv('el_nino_la_nina_1999_2019.csv')
weatherdf
# Out:
#     start year  end year phenomenon     severity
# 0         2004      2005    El Nino         Weak
# 1         2006      2007    El Nino         Weak
# 2         2014      2015    El Nino         Weak
# 3         2018      2019    El Nino         Weak
# 4         2002      2003    El Nino     Moderate
# 5         2009      2010    El Nino     Moderate
# 6         2015      2016    El Nino  Very Strong
# 7         2000      2001    La Nina         Weak
# 8         2005      2006    La Nina         Weak
# 9         2008      2009    La Nina         Weak
# 10        2016      2017    La Nina         Weak
# 11        2017      2018    La Nina         Weak
# 12        2011      2012    La Nina     Moderate
# 13        1999      2000    La Nina       Strong
# 14        2007      2008    La Nina       Strong
# 15        2010      2011    La Nina       Strong

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
alpha_map = {
    "Weak": .125,
    "Moderate": .25,
    "Strong": .375,
    "Very Strong": .5
}

weatherdf['alpha'] = weatherdf["severity"].map(alpha_map)

# %%
el_nino = weatherdf[weatherdf['phenomenon'] == 'El Nino'].copy()
la_nina= weatherdf[weatherdf['phenomenon'] == 'La Nina'].copy()

# %%
fig, ax = plt.subplots(figsize=(12,5))
#graph inspired from https://www.kaggle.com/mbogernetto/is-brazilian-amazon-degradation-increasing
for i, row in el_nino.iterrows(): #generate a list of rows
    ax.axvspan(row["start year"]+.5, row["end year"]+.5, alpha=row["alpha"], color='darkorange', label='El Nino')

for i, row in la_nina.iterrows(): #generate a list of rows
    ax.axvspan(row["start year"]+.5, row["end year"]+.5, alpha=row["alpha"], color='lightblue', label='La Nina')

sns.lineplot(x=rawdf['Year'], y=rawdf['Total'], estimator='sum', color="black", ci=None, ax=ax)
ax.grid(False)

plt.xticks(ticks=list(range(2003, 2020)), rotation=90)
ax.set_xlim(2003, 2020)

plt.title("Total Deforested Area By Year & Weather Phenomena From 2004-2019", fontsize=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Deforested Area in km2', fontsize=14)

legend_elements = [Line2D([0], [0], color='black', lw=2, label='Deforested Area'),
                   Patch(facecolor='darkorange', edgecolor='darkorange', label='El Nino', alpha=.5),
                   Patch(facecolor='lightblue', edgecolor='lightblue', label='La Nina', alpha=.5)]

ax.legend(handles=legend_elements);

# %%
firedf= pd.read_csv('inpe_brazilian_amazon_fires_1999_2019.csv')
firedf
# Out:
#       year  month        state   latitude  longitude  firespots
# 0     1999      1     AMAZONAS  -2.371113 -59.899933          3
# 1     1999      1     MARANHAO  -2.257395 -45.487831         36
# 2     1999      1  MATO GROSSO -12.660633 -55.057989         18
# 3     1999      1         PARA  -2.474820 -48.546967         87
# 4     1999      1     RONDONIA -12.861700 -60.513100          1
# ...    ...    ...          ...        ...        ...        ...
# 2099  2019     12  MATO GROSSO -12.138385 -56.066297        148
# 2100  2019     12         PARA  -2.976727 -50.909316       1280
# 2101  2019     12     RONDONIA -10.809262 -62.890452         42
# 2102  2019     12      RORAIMA   2.856667 -60.431963         27
# 2103  2019     12    TOCANTINS  -6.769381 -48.475667         21
#
# [2104 rows x 6 columns]

# %%
firedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       2104 non-null   int64
#  1   month      2104 non-null   int64
#  2   state      2104 non-null   object
#  3   latitude   2104 non-null   float64
#  4   longitude  2104 non-null   float64
#  5   firespots  2104 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 98.8+ KB

# %%
firedf.describe()
# Out:
#               year        month     latitude    longitude     firespots
# count  2104.000000  2104.000000  2104.000000  2104.000000   2104.000000
# mean   2009.267110     6.704848    -5.439282   -56.510314   1167.417776
# std       5.963029     3.431949     4.852439     7.382619   2959.558714
# min    1999.000000     1.000000   -14.431908   -73.085000      1.000000
# 25%    2004.000000     4.000000    -9.946974   -62.376004     16.000000
# 50%    2009.000000     7.000000    -5.808292   -55.876480    121.000000
# 75%    2014.000000    10.000000    -2.595169   -50.396154    755.000000
# max    2019.000000    12.000000     4.151000   -44.188000  37926.000000

# %%
statefires = pd.pivot_table(firedf, values='firespots',index=['year'], columns=['state'], 
                     aggfunc=sum, fill_value=0)
sns.heatmap(statefires, cmap= 'Reds')
plt.title('FireSpots in Each State From 1999 to 2019')
# Out:
# Text(0.5, 1.0, 'FireSpots in Each State From 1999 to 2019')

# %%
yearlyfiredf=firedf.drop(["month","state","latitude","longitude"],axis=1)
yearlyfiredf
# Out:
#       year  firespots
# 0     1999          3
# 1     1999         36
# 2     1999         18
# 3     1999         87
# 4     1999          1
# ...    ...        ...
# 2099  2019        148
# 2100  2019       1280
# 2101  2019         42
# 2102  2019         27
# 2103  2019         21
#
# [2104 rows x 2 columns]

# %%
plt.figure(figsize=(12,5))
fireyear = list(range(1999, 2020))
sns.set_style("darkgrid")
sns.lineplot(data=yearlyfiredf, x='year', y='firespots', ci= None, estimator='sum', color="orange")
plt.ylabel("Total Firespots", fontsize= 14)
plt.xlabel("Year", fontsize= 14)
plt.xticks(fireyear, rotation=90)
plt.title("Total Fire Outbreaks Determined Per Year", fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Total Fire Outbreaks Determined Per Year')

# %%
p= {'Year': [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'Population': [184006481, 186127103, 188167356, 190130443, 192030362, 193886508, 195713635, 197514536, 199287299, 201035912, 202763739, 204471769, 206163053, 207833823, 209469323, 211049527]}
popdf=pd.DataFrame(data=p)
popdf
# Out:
#     Year  Population
# 0   2004   184006481
# 1   2005   186127103
# 2   2006   188167356
# 3   2007   190130443
# 4   2008   192030362
# 5   2009   193886508
# 6   2010   195713635
# 7   2011   197514536
# 8   2012   199287299
# 9   2013   201035912
# 10  2014   202763739
# 11  2015   204471769
# 12  2016   206163053
# 13  2017   207833823
# 14  2018   209469323
# 15  2019   211049527

# %%
plt.figure(figsize=(12,5))
popyears = list(range(2004, 2019))
sns.set_style("darkgrid")
sns.lineplot(data=popdf, x='Year', y='Population', ci= None, color="salmon")
plt.ylabel("Population", fontsize=14)
plt.xlabel("Year", fontsize=14)
plt.xticks(popyears, rotation=90)
plt.title("Total Population Per Year", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Population Per Year')

# %%
d= {'Year': [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'GDP per capita(US$)':[3637.462, 4790.437, 5886.464, 7348.031, 8831.023, 8597.915, 11286.243, 13245.612, 12370.024, 12300.325, 12112.588, 8814.001, 8710.097, 9925.386, 9001.234, 8717.186] }
gdpdf= pd.DataFrame(data=d)
gdpdf
# Out:
#     Year  GDP per capita(US$)
# 0   2004             3637.462
# 1   2005             4790.437
# 2   2006             5886.464
# 3   2007             7348.031
# 4   2008             8831.023
# 5   2009             8597.915
# 6   2010            11286.243
# 7   2011            13245.612
# 8   2012            12370.024
# 9   2013            12300.325
# 10  2014            12112.588
# 11  2015             8814.001
# 12  2016             8710.097
# 13  2017             9925.386
# 14  2018             9001.234
# 15  2019             8717.186

# %%
plt.figure(figsize=(12,5))
gdpyears = list(range(2004, 2019))
sns.set_style("darkgrid")
sns.lineplot(data=gdpdf, x='Year', y='GDP per capita(US$)', ci= None, color="gold")
plt.ylabel("GDP per capita(US$)", fontsize= 14)
plt.xlabel("Year", fontsize=14)
plt.xticks(gdpyears, rotation=90)
plt.title("Total GDP Per Year", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total GDP Per Year')

# %%
merge1=pd.merge(rawdf, popdf, on= 'Year')
merge1
# Out:
#     Year  Acre  Amazonas  Amapa  Maranhao  Mato Grosso  Para  Rondonia  \
# 0   2004   728      1232     46       755        11814  8870      3858
# 1   2005   592       775     33       922         7145  5899      3244
# 2   2006   398       788     30       674         4333  5659      2049
# 3   2007   184       610     39       631         2678  5526      1611
# 4   2008   254       604    100      1271         3258  5607      1136
# 5   2009   167       405     70       828         1049  4281       482
# 6   2010   259       595     53       712          871  3770       435
# 7   2011   280       502     66       396         1120  3008       865
# 8   2012   305       523     27       269          757  1741       773
# 9   2013   221       583     23       403         1139  2346       932
# 10  2014   309       500     31       257         1075  1887       684
# 11  2015   264       712     25       209         1601  2153      1030
# 12  2016   372      1129     17       258         1489  2992      1376
# 13  2017   257      1001     24       265         1561  2433      1243
# 14  2018   444      1045     24       253         1490  2744      1316
# 15  2019   688      1421      8       215         1685  3862      1245
#
#     Roraima  Tocantins  Total  Population
# 0       311        158  27772   184006481
# 1       133        271  19014   186127103
# 2       231        124  14286   188167356
# 3       309         63  11651   190130443
# 4       574        107  12911   192030362
# 5       121         61   7464   193886508
# 6       256         49   7000   195713635
# 7       141         40   6418   197514536
# 8       124         52   4571   199287299
# 9       170         74   5891   201035912
# 10      219         50   5012   202763739
# 11      156         57   6207   204471769
# 12      202         58   7893   206163053
# 13      132         31   6947   207833823
# 14      195         25   7536   209469323
# 15      617         21   9762   211049527

# %%
merge2=pd.merge(merge1, gdpdf, on= 'Year')
merge2
# Out:
#     Year  Acre  Amazonas  Amapa  Maranhao  Mato Grosso  Para  Rondonia  \
# 0   2004   728      1232     46       755        11814  8870      3858
# 1   2005   592       775     33       922         7145  5899      3244
# 2   2006   398       788     30       674         4333  5659      2049
# 3   2007   184       610     39       631         2678  5526      1611
# 4   2008   254       604    100      1271         3258  5607      1136
# 5   2009   167       405     70       828         1049  4281       482
# 6   2010   259       595     53       712          871  3770       435
# 7   2011   280       502     66       396         1120  3008       865
# 8   2012   305       523     27       269          757  1741       773
# 9   2013   221       583     23       403         1139  2346       932
# 10  2014   309       500     31       257         1075  1887       684
# 11  2015   264       712     25       209         1601  2153      1030
# 12  2016   372      1129     17       258         1489  2992      1376
# 13  2017   257      1001     24       265         1561  2433      1243
# 14  2018   444      1045     24       253         1490  2744      1316
# 15  2019   688      1421      8       215         1685  3862      1245
#
#     Roraima  Tocantins  Total  Population  GDP per capita(US$)
# 0       311        158  27772   184006481             3637.462
# 1       133        271  19014   186127103             4790.437
# 2       231        124  14286   188167356             5886.464
# 3       309         63  11651   190130443             7348.031
# 4       574        107  12911   192030362             8831.023
# 5       121         61   7464   193886508             8597.915
# 6       256         49   7000   195713635            11286.243
# 7       141         40   6418   197514536            13245.612
# 8       124         52   4571   199287299            12370.024
# 9       170         74   5891   201035912            12300.325
# 10      219         50   5012   202763739            12112.588
# 11      156         57   6207   204471769             8814.001
# 12      202         58   7893   206163053             8710.097
# 13      132         31   6947   207833823             9925.386
# 14      195         25   7536   209469323             9001.234
# 15      617         21   9762   211049527             8717.186

# %%
for year in yearlyfiredf['year'].unique():
    #Calculates total firespots for each year in the yearly fires dataset
    print(year)
    print(yearlyfiredf[yearlyfiredf['year']==year]['firespots'].sum())
# Out:
# 1999
# 62858
# 2000
# 48168
# 2001
# 69675
# 2002
# 273873
# 2003
# 174400
# 2004
# 218637
# 2005
# 213720
# 2006
# 144422
# 2007
# 186480
# 2008
# 103453
# 2009
# 81682
# 2010
# 134614
# 2011
# 58186
# 2012
# 86719
# 2013
# 58688
# 2014
# 82554
# 2015
# 106438
# 2016
# 87761
# 2017
# 107439
# 2018
# 68345
# 2019
# 88135

# %%
f={'Year':[2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'firespots':[218637, 213720, 144422, 186480, 103453, 81682, 134614, 58186, 86719, 58688, 82554, 106438, 87761, 107439, 68345, 88135]}
firespotsdf= pd.DataFrame(data= f)
firespotsdf
# Out:
#     Year  firespots
# 0   2004     218637
# 1   2005     213720
# 2   2006     144422
# 3   2007     186480
# 4   2008     103453
# 5   2009      81682
# 6   2010     134614
# 7   2011      58186
# 8   2012      86719
# 9   2013      58688
# 10  2014      82554
# 11  2015     106438
# 12  2016      87761
# 13  2017     107439
# 14  2018      68345
# 15  2019      88135

# %%
merge3=pd.merge(merge2, firespotsdf, on= 'Year')
merge3
# Out:
#     Year  Acre  Amazonas  Amapa  Maranhao  Mato Grosso  Para  Rondonia  \
# 0   2004   728      1232     46       755        11814  8870      3858
# 1   2005   592       775     33       922         7145  5899      3244
# 2   2006   398       788     30       674         4333  5659      2049
# 3   2007   184       610     39       631         2678  5526      1611
# 4   2008   254       604    100      1271         3258  5607      1136
# 5   2009   167       405     70       828         1049  4281       482
# 6   2010   259       595     53       712          871  3770       435
# 7   2011   280       502     66       396         1120  3008       865
# 8   2012   305       523     27       269          757  1741       773
# 9   2013   221       583     23       403         1139  2346       932
# 10  2014   309       500     31       257         1075  1887       684
# 11  2015   264       712     25       209         1601  2153      1030
# 12  2016   372      1129     17       258         1489  2992      1376
# 13  2017   257      1001     24       265         1561  2433      1243
# 14  2018   444      1045     24       253         1490  2744      1316
# 15  2019   688      1421      8       215         1685  3862      1245
#
#     Roraima  Tocantins  Total  Population  GDP per capita(US$)  firespots
# 0       311        158  27772   184006481             3637.462     218637
# 1       133        271  19014   186127103             4790.437     213720
# 2       231        124  14286   188167356             5886.464     144422
# 3       309         63  11651   190130443             7348.031     186480
# 4       574        107  12911   192030362             8831.023     103453
# 5       121         61   7464   193886508             8597.915      81682
# 6       256         49   7000   195713635            11286.243     134614
# 7       141         40   6418   197514536            13245.612      58186
# 8       124         52   4571   199287299            12370.024      86719
# 9       170         74   5891   201035912            12300.325      58688
# 10      219         50   5012   202763739            12112.588      82554
# 11      156         57   6207   204471769             8814.001     106438
# 12      202         58   7893   206163053             8710.097      87761
# 13      132         31   6947   207833823             9925.386     107439
# 14      195         25   7536   209469323             9001.234      68345
# 15      617         21   9762   211049527             8717.186      88135

# %%
correlatecols = [c for c in merge3.columns.to_list() if c not in ['Year']]

# %%
merge3[correlatecols].corr()
# Out:
#                          Acre  Amazonas     Amapa  Maranhao  Mato Grosso  \
# Acre                 1.000000  0.775866 -0.339829 -0.010346     0.683814
# Amazonas             0.775866  1.000000 -0.515584 -0.275769     0.384845
# Amapa               -0.339829 -0.515584  1.000000  0.776842     0.102960
# Maranhao            -0.010346 -0.275769  0.776842  1.000000     0.473415
# Mato Grosso          0.683814  0.384845  0.102960  0.473415     1.000000
# Para                 0.504576  0.270740  0.362181  0.717961     0.874059
# Rondonia             0.735137  0.494205 -0.112198  0.328803     0.951961
# Roraima              0.355792  0.411181  0.202645  0.297728     0.145706
# Tocantins            0.437920  0.014299  0.151954  0.622936     0.768981
# Total                0.680878  0.412682  0.163222  0.561771     0.980933
# Population          -0.100513  0.308319 -0.520491 -0.793987    -0.685199
# GDP per capita(US$) -0.589384 -0.481485  0.026654 -0.457321    -0.817482
# firespots            0.443660  0.207353  0.039982  0.500669     0.816705
#
#                          Para  Rondonia   Roraima  Tocantins     Total  \
# Acre                 0.504576  0.735137  0.355792   0.437920  0.680878
# Amazonas             0.270740  0.494205  0.411181   0.014299  0.412682
# Amapa                0.362181 -0.112198  0.202645   0.151954  0.163222
# Maranhao             0.717961  0.328803  0.297728   0.622936  0.561771
# Mato Grosso          0.874059  0.951961  0.145706   0.768981  0.980933
# Para                 1.000000  0.788527  0.369552   0.664631  0.942646
# Rondonia             0.788527  1.000000  0.074951   0.784959  0.934940
# Roraima              0.369552  0.074951  1.000000  -0.063089  0.269753
# Tocantins            0.664631  0.784959 -0.063089   1.000000  0.757374
# Total                0.942646  0.934940  0.269753   0.757374  1.000000
# Population          -0.796101 -0.573035  0.018148  -0.747489 -0.709597
# GDP per capita(US$) -0.831159 -0.848464 -0.204670  -0.681220 -0.864801
# firespots            0.805791  0.814925  0.085596   0.742040  0.833778
#
#                      Population  GDP per capita(US$)  firespots
# Acre                  -0.100513            -0.589384   0.443660
# Amazonas               0.308319            -0.481485   0.207353
# Amapa                 -0.520491             0.026654   0.039982
# Maranhao              -0.793987            -0.457321   0.500669
# Mato Grosso           -0.685199            -0.817482   0.816705
# Para                  -0.796101            -0.831159   0.805791
# Rondonia              -0.573035            -0.848464   0.814925
# Roraima                0.018148            -0.204670   0.085596
# Tocantins             -0.747489            -0.681220   0.742040
# Total                 -0.709597            -0.864801   0.833778
# Population             1.000000             0.549045  -0.737390
# GDP per capita(US$)    0.549045             1.000000  -0.806311
# firespots             -0.737390            -0.806311   1.000000

# %%
corrgraph=merge3[correlatecols].corr()
corrgraph['Total'].sort_values()
# Out:
# GDP per capita(US$)   -0.864801
# Population            -0.709597
# Amapa                  0.163222
# Roraima                0.269753
# Amazonas               0.412682
# Maranhao               0.561771
# Acre                   0.680878
# Tocantins              0.757374
# firespots              0.833778
# Rondonia               0.934940
# Para                   0.942646
# Mato Grosso            0.980933
# Total                  1.000000
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.bar(corrgraph.columns, corrgraph['Total'], color='purple', align= 'center')
plt.title('Deforestation Correlation Percentages', fontsize=20)
plt.xticks(rotation= 90, fontsize= 14)
plt.ylabel('Percent', fontsize= 14)
# Out:
# Text(0, 0.5, 'Percent')

# %%
colsformodel = [c for c in merge3.columns.to_list() if c in ['Population','GDP per capita(US$)','firespots' ]]
colsformodel
# Out:
# ['Population', 'GDP per capita(US$)', 'firespots']

# %%
X= merge3[colsformodel]
y= merge3['Total']

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state= 42)

# %%
scaler= StandardScaler()
scaler.fit(X_train)
X_train_scaled= scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
lr= LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
train_preds= lr.predict(X_train_scaled)
test_preds= lr.predict(X_test_scaled)

# %%
r2_score(y_train, train_preds)
# Out:
# 0.8600090384548267

# %%
r2_score(y_test, test_preds)
# Out:
# 0.4421258611460134

# %%
dict(zip(X.columns, lr.coef_))
# Out:
# {'Population': -1558.8396708864086,
#  'GDP per capita(US$)': -2820.806724410068,
#  'firespots': -998.6960105368757}

# %%
print(f"RMSE train: {np.sqrt(mean_squared_error(y_train, train_preds))}")
# Out:
# RMSE train: 1145.5896754079492

# %%
print(f"RMSE test: {np.sqrt(mean_squared_error(y_test, test_preds))}")
# Out:
# RMSE test: 6370.020408634194

# %%
from sklearn.linear_model import Ridge

# %%
clf= Ridge()
clf.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
train_predsr= clf.predict(X_train_scaled)
test_predsr= clf.predict(X_test_scaled)

# %%
r2_score(y_train, train_predsr)
# Out:
# 0.8443697264016197

# %%
r2_score(y_test, test_predsr)
# Out:
# 0.4442844054540963

# %%
dict(zip(X.columns, clf.coef_))
# Out:
# {'Population': -1281.9924508078784,
#  'GDP per capita(US$)': -2322.7232769772604,
#  'firespots': -456.86363181979533}

# %%
print(f"RMSE train: {np.sqrt(mean_squared_error(y_train, train_predsr))}")
# Out:
# RMSE train: 1207.8865159370596

# %%
print(f"RMSE test: {np.sqrt(mean_squared_error(y_test, test_predsr))}")
# Out:
# RMSE test: 6357.684922377736

# %%
states_piv = pd.pivot_table(firedf, values='firespots', index=['month'], columns= ['state'], aggfunc=sum, fill_value=0) 
states_list = ['ACRE', 'AMAZONAS', 'AMAPA', 'MARANHAO', 'MATO GROSSO', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS']

# %%
fig, ax = plt.subplots(3,3, figsize=(15,10))
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.suptitle('Monthly Amazon Fire Outbreaks Per State from 1999-2019', fontsize=16)
for i in range(3):
    for j in range(3):
        #Creates subplots of the different states and total monthly firespots amounts
        col = states_list[i*3+j]
        piv_plot = states_piv[[col]]
        ax[i,j].plot(piv_plot.index, piv_plot[col], linewidth=2, color='orangered')
        ax[i,j].set_ylabel('Firespots', fontsize=12)
        ax[i,j].set_xlabel('Month', fontsize=12)
        ax[i,j].set_title(states_list[i*3+j])

# %%
stats_2004= previous_year(firedf, 2004)
stats_2004
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-c2cb562efe92> in <module>
# ----> 1 stats_2004= previous_year(firedf, 2004)
#       2 stats_2004
#
# NameError: name 'previous_year' is not defined

# %%
def plot_year_row(dataset, year):  
    '''Creates graph of firespots by month'''
    #function inspired from https://www.kaggle.com/mbogernetto/is-brazilian-amazon-degradation-increasing
    #Creates bar graph of number of firespots per month for reference year
    plt.bar(dataset.index, dataset[f'{year}'], align='center', color='brown', alpha=1, label=f"{year}", linewidth=1)
    #Creates line plots of minimum, maximum, and mean number of firespots by month excluding reference year
    sns.lineplot(data=dataset, x=dataset.index, y='min', color="yellow", lw=4, alpha=0.7, label="Minimum")
    sns.lineplot(data=dataset, x=dataset.index, y='mean', color="orange", lw=4, alpha=0.7, label="Average")
    sns.lineplot(data=dataset, x=dataset.index, y='max', color="red", lw=4, alpha=0.7, label="Maximum")
    plt.ylabel("Fire Outbreaks", size='12')
    plt.xlabel("Month", size= '12')
    plt.title(f"{year} vs Previous Years Total", size='16')

# %%
plot_year_row(stats_2004, 2004)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5909530ccd54> in <module>
# ----> 1 plot_year_row(stats_2004, 2004)
#
# NameError: name 'stats_2004' is not defined

# %%
stats_2019= previous_year(firedf, 2019)
stats_2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-eedec4528124> in <module>
# ----> 1 stats_2019= previous_year(firedf, 2019)
#       2 stats_2019
#
# NameError: name 'previous_year' is not defined

# %%
plot_year_row(stats_2019, 2019)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-5a2153304837> in <module>
# ----> 1 plot_year_row(stats_2019, 2019)
#
# NameError: name 'stats_2019' is not defined

# %%
yearmonthcols= ['year', 'month']
firedf['date']=pd.to_datetime(firedf[yearmonthcols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns"))

# %%
firedf
# Out:
#       year  month        state   latitude  longitude  firespots       date
# 0     1999      1     AMAZONAS  -2.371113 -59.899933          3 1999-01-01
# 1     1999      1     MARANHAO  -2.257395 -45.487831         36 1999-01-01
# 2     1999      1  MATO GROSSO -12.660633 -55.057989         18 1999-01-01
# 3     1999      1         PARA  -2.474820 -48.546967         87 1999-01-01
# 4     1999      1     RONDONIA -12.861700 -60.513100          1 1999-01-01
# ...    ...    ...          ...        ...        ...        ...        ...
# 2099  2019     12  MATO GROSSO -12.138385 -56.066297        148 2019-12-01
# 2100  2019     12         PARA  -2.976727 -50.909316       1280 2019-12-01
# 2101  2019     12     RONDONIA -10.809262 -62.890452         42 2019-12-01
# 2102  2019     12      RORAIMA   2.856667 -60.431963         27 2019-12-01
# 2103  2019     12    TOCANTINS  -6.769381 -48.475667         21 2019-12-01
#
# [2104 rows x 7 columns]

# %%
firedf.set_index('date')['firespots']
# Out:
# date
# 1999-01-01       3
# 1999-01-01      36
# 1999-01-01      18
# 1999-01-01      87
# 1999-01-01       1
#               ...
# 2019-12-01     148
# 2019-12-01    1280
# 2019-12-01      42
# 2019-12-01      27
# 2019-12-01      21
# Name: firespots, Length: 2104, dtype: int64

# %%
Amazonasts=firedf.loc[firedf['state']=='AMAZONAS']

# %%
Amazonasts=Amazonasts.set_index('date')['firespots']

# %%
Amazonasts.plot(color='dodgerblue', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Amazonas", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Amazonas')

# %%
from sklearn import metrics
def report_metrics(y_true, y_pred):
    #Returns mean absolute error, root mean squared error, and r2(the coefficient of determination) for a model
    print("MAE:\n\t", metrics.mean_absolute_error(y_true, y_pred))
    print("RMSE:\n\t", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("R2:\n\t", metrics.r2_score(y_true, y_pred))

# %%
import pmdarima as pm
from pmdarima import model_selection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-76-d3b77004608c> in <module>
# ----> 1 import pmdarima as pm
#       2 from pmdarima import model_selection
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
Amazonastsdf=pd.DataFrame(Amazonasts)

# %%
Amazonastsdfar=Amazonastsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Amazonastsdfar, test_size=12)

# %%
arima = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=3827.664, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4097.432, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=3863.413, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=3901.294, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=4169.019, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=3874.849, Time=0.14 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=3832.665, Time=0.21 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=3911.210, Time=0.45 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=3811.834, Time=0.47 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=3845.036, Time=0.40 sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=4148.187, Time=0.52 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=3810.773, Time=0.41 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=3846.388, Time=0.36 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=3821.837, Time=0.18 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=4071.213, Time=0.50 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=3876.780, Time=0.14 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=3933.422, Time=0.37 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=3819.185, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=3821.355, Time=0.37 sec
#  ARIMA(1,0,3)(1,0,2)[12] intercept   : AIC=3808.399, Time=0.50 sec
#  ARIMA(1,0,3)(0,0,2)[12] intercept   : AIC=3846.736, Time=0.43 sec
#  ARIMA(1,0,3)(1,0,1)[12] intercept   : AIC=3816.080, Time=0.21 sec
#  ARIMA(1,0,3)(2,0,2)[12] intercept   : AIC=4108.836, Time=0.67 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=3876.272, Time=0.20 sec
#  ARIMA(1,0,3)(2,0,1)[12] intercept   : AIC=3810.103, Time=0.65 sec
#  ARIMA(0,0,3)(1,0,2)[12] intercept   : AIC=3815.355, Time=0.54 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=3809.618, Time=0.53 sec
#  ARIMA(1,0,4)(1,0,2)[12] intercept   : AIC=3798.902, Time=0.54 sec
#  ARIMA(1,0,4)(0,0,2)[12] intercept   : AIC=3850.697, Time=0.54 sec
#  ARIMA(1,0,4)(1,0,1)[12] intercept   : AIC=3800.801, Time=0.22 sec
#  ARIMA(1,0,4)(2,0,2)[12] intercept   : AIC=3936.422, Time=0.67 sec
#  ARIMA(1,0,4)(0,0,1)[12] intercept   : AIC=3885.317, Time=0.22 sec
#  ARIMA(1,0,4)(2,0,1)[12] intercept   : AIC=3833.009, Time=0.46 sec
#  ARIMA(0,0,4)(1,0,2)[12] intercept   : AIC=3829.058, Time=0.55 sec
#  ARIMA(2,0,4)(1,0,2)[12] intercept   : AIC=3797.935, Time=0.64 sec
#  ARIMA(2,0,4)(0,0,2)[12] intercept   : AIC=3849.779, Time=0.59 sec
#  ARIMA(2,0,4)(1,0,1)[12] intercept   : AIC=3801.693, Time=0.24 sec
#  ARIMA(2,0,4)(2,0,2)[12] intercept   : AIC=3930.656, Time=0.67 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=3879.249, Time=0.23 sec
#  ARIMA(2,0,4)(2,0,1)[12] intercept   : AIC=3823.151, Time=0.52 sec
#  ARIMA(3,0,4)(1,0,2)[12] intercept   : AIC=3774.583, Time=0.63 sec
#  ARIMA(3,0,4)(0,0,2)[12] intercept   : AIC=3831.939, Time=0.57 sec
#  ARIMA(3,0,4)(1,0,1)[12] intercept   : AIC=3788.241, Time=0.25 sec
#  ARIMA(3,0,4)(2,0,2)[12] intercept   : AIC=3929.312, Time=0.75 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=3871.796, Time=0.23 sec
#  ARIMA(3,0,4)(2,0,1)[12] intercept   : AIC=3825.947, Time=0.62 sec
#  ARIMA(3,0,3)(1,0,2)[12] intercept   : AIC=3812.643, Time=0.63 sec
#  ARIMA(4,0,4)(1,0,2)[12] intercept   : AIC=3771.266, Time=0.70 sec
#  ARIMA(4,0,4)(0,0,2)[12] intercept   : AIC=3829.513, Time=0.63 sec
#  ARIMA(4,0,4)(1,0,1)[12] intercept   : AIC=3785.507, Time=0.28 sec
#  ARIMA(4,0,4)(2,0,2)[12] intercept   : AIC=4049.955, Time=0.79 sec
#  ARIMA(4,0,4)(0,0,1)[12] intercept   : AIC=3871.496, Time=0.28 sec
#  ARIMA(4,0,4)(2,0,1)[12] intercept   : AIC=3847.947, Time=0.63 sec
#  ARIMA(4,0,3)(1,0,2)[12] intercept   : AIC=3820.894, Time=0.69 sec
#  ARIMA(5,0,4)(1,0,2)[12] intercept   : AIC=3758.632, Time=0.73 sec
#  ARIMA(5,0,4)(0,0,2)[12] intercept   : AIC=3843.857, Time=0.68 sec
#  ARIMA(5,0,4)(1,0,1)[12] intercept   : AIC=3763.834, Time=0.34 sec
#  ARIMA(5,0,4)(2,0,2)[12] intercept   : AIC=3916.163, Time=0.89 sec
#  ARIMA(5,0,4)(0,0,1)[12] intercept   : AIC=3899.299, Time=0.27 sec
#  ARIMA(5,0,4)(2,0,1)[12] intercept   : AIC=3780.081, Time=0.77 sec
#  ARIMA(5,0,3)(1,0,2)[12] intercept   : AIC=3823.456, Time=0.73 sec
#  ARIMA(5,0,5)(1,0,2)[12] intercept   : AIC=3758.770, Time=0.80 sec
#  ARIMA(4,0,5)(1,0,2)[12] intercept   : AIC=3757.464, Time=0.77 sec
#  ARIMA(4,0,5)(0,0,2)[12] intercept   : AIC=3833.061, Time=0.68 sec
#  ARIMA(4,0,5)(1,0,1)[12] intercept   : AIC=3774.111, Time=0.31 sec
#  ARIMA(4,0,5)(2,0,2)[12] intercept   : AIC=3978.239, Time=0.87 sec
#  ARIMA(4,0,5)(0,0,1)[12] intercept   : AIC=3886.945, Time=0.28 sec
#  ARIMA(4,0,5)(2,0,1)[12] intercept   : AIC=3813.895, Time=0.69 sec
#  ARIMA(3,0,5)(1,0,2)[12] intercept   : AIC=3754.699, Time=0.71 sec
#  ARIMA(3,0,5)(0,0,2)[12] intercept   : AIC=3830.530, Time=0.62 sec
#  ARIMA(3,0,5)(1,0,1)[12] intercept   : AIC=3764.172, Time=0.30 sec
#  ARIMA(3,0,5)(2,0,2)[12] intercept   : AIC=4052.699, Time=0.80 sec
#  ARIMA(3,0,5)(0,0,1)[12] intercept   : AIC=3883.666, Time=0.26 sec
#  ARIMA(3,0,5)(2,0,1)[12] intercept   : AIC=3811.193, Time=0.68 sec
#  ARIMA(2,0,5)(1,0,2)[12] intercept   : AIC=3753.722, Time=0.65 sec
#  ARIMA(2,0,5)(0,0,2)[12] intercept   : AIC=3828.605, Time=0.67 sec
#  ARIMA(2,0,5)(1,0,1)[12] intercept   : AIC=3768.607, Time=0.28 sec
#  ARIMA(2,0,5)(2,0,2)[12] intercept   : AIC=4021.898, Time=0.80 sec
#  ARIMA(2,0,5)(0,0,1)[12] intercept   : AIC=3880.933, Time=0.26 sec
#  ARIMA(2,0,5)(2,0,1)[12] intercept   : AIC=3824.382, Time=0.56 sec
#  ARIMA(1,0,5)(1,0,2)[12] intercept   : AIC=3776.792, Time=0.60 sec
#  ARIMA(2,0,5)(1,0,2)[12]             : AIC=3755.201, Time=0.58 sec
#
# Best model:  ARIMA(2,0,5)(1,0,2)[12] intercept
# Total fit time: 39.611 seconds

# %% [markdown]
# I graphed my predicted values of firespots with the true values of firespots for 2019 for the Brazilian state of Amazonas below.

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='dodgerblue')
plt.plot(x, arima.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %% [markdown]
# The cell below shows the predicted firespots by month for Amazonas in Brazil for the year 2019.

# %%
arima.predict(n_periods=test.shape[0])
# Out:
# array([ 182.47111643,  140.32613697,  186.67051829,  205.74927788,
#         178.55800459,  240.69258153, 1267.0764539 , 3599.30763975,
#        3224.76375832, 1527.03137011,  616.86545336,  328.52562103])

# %% [markdown]
# The predicted total of firespots for Amazonas in Brazil in 2019 was about 11698.

# %%
arima.predict(n_periods=test.shape[0]).sum()
# Out:
# 11698.037932163254

# %% [markdown]
# The actual total of firespots for Amazonas in Brazil in 2019 was 12665.

# %%
test.sum()
# Out:
# 12665

# %% [markdown]
# The actual total of firespots exceeded the predicted total of firespots for Amazonas in Brazil in 2019.

# %% [markdown]
# I got the values for Mean Absolute Error(MAE), Root Mean Squared Error(RMSE), and R2 for my Amazonas time series model. The values show my model did well at predicting firespots. My Amazonas model explains a lot of the variability of the data in comparison to its mean value.

# %%
report_metrics(test, arima.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 448.1891454048864
# RMSE:
# 	 939.2024345603973
# R2:
# 	 0.7527369992902428

# %% [markdown]
# #### State Time Series Combined

# %% [markdown]
# I produced a set of time series to involve all Brazilian states that include the Amazon to show fire outbreaks per year between 1999-2019.

# %%
for state in firedf['state'].unique():
    #Calculates and Graphs Total Fire Outbreaks Per State Per Year
    firedf.loc[firedf['state']==state].set_index('date')['firespots'].plot(figsize=(15,10))
    plt.legend(firedf['state'].unique())
    plt.xticks(rotation= 90)
    plt.xlabel("Year", fontsize= 14)
    plt.ylabel("Fire Outbreaks", fontsize= 14)
    plt.title("Fire Outbreaks Per Year Across Brazilian States", fontsize= 20)

# %% [markdown]
# The group of time series graph above showed that most all of the Brazilian states follow similar seasonality trends.  The Brazilian states of Mato Grosso, Para, and Rondonia appear to lead the group of trends with their high firespot totals. Roraima was the only Brazilian state that seemed to have its own trend line and followed a different pattern than the other Brazilian states, but its trend was still a seasonal trend.

# %% [markdown]
# #### Maranhao Time Series Exploration

# %% [markdown]
# I procured a Maranhao state time series in the next few cells.

# %%
Maranhaots=firedf.loc[firedf['state']=='MARANHAO']

# %%
Maranhaots=Maranhaots.set_index('date')['firespots']

# %% [markdown]
# I plotted my Maranhao time series to show fire outbreaks per year for the Brazilian state of Maranhao between 1999-2019.

# %%
Maranhaots.plot(color='orange', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Maranhao", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Maranhao')

# %% [markdown]
# Fire outbreaks are generally decreasing from the year 2003 to the year 2014. Then fire outbreaks vary.

# %% [markdown]
# I designed an arima model to predict firespots for the year 2019 for the state of Maranhao in Brazil.

# %%
Maranhaotsdf=pd.DataFrame(Maranhaots)

# %%
Maranhaotsdfar=Maranhaotsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Maranhaotsdfar, test_size=12)

# %%
arima1 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=3853.530, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4064.484, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=3832.502, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=3864.607, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=4130.268, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=3930.193, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=3817.782, Time=0.61 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=3813.033, Time=0.36 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=3832.513, Time=0.10 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=3815.026, Time=0.31 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=3818.318, Time=0.31 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=3946.959, Time=0.20 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=3774.793, Time=0.37 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=3807.960, Time=0.14 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=3789.574, Time=0.54 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=3775.408, Time=0.40 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=3806.295, Time=0.25 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=3779.324, Time=0.31 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=3773.859, Time=0.42 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=3804.734, Time=0.18 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=3785.619, Time=0.91 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=3774.833, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=3804.001, Time=0.28 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : AIC=3778.912, Time=0.43 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : AIC=3774.424, Time=0.46 sec
#  ARIMA(3,0,1)(2,0,1)[12] intercept   : AIC=3770.214, Time=0.46 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=3788.233, Time=0.17 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : AIC=3772.124, Time=0.47 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : AIC=3772.475, Time=0.49 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=3796.784, Time=0.25 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=3776.632, Time=0.41 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=3770.596, Time=0.41 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : AIC=3768.586, Time=0.52 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : AIC=3791.605, Time=0.21 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : AIC=3772.716, Time=0.52 sec
#  ARIMA(4,0,1)(2,0,2)[12] intercept   : AIC=3771.069, Time=0.52 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : AIC=3797.213, Time=0.26 sec
#  ARIMA(4,0,1)(1,0,2)[12] intercept   : AIC=3775.371, Time=0.48 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : AIC=3770.169, Time=0.67 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : AIC=3769.494, Time=0.53 sec
#  ARIMA(3,0,2)(2,0,1)[12] intercept   : AIC=3779.326, Time=0.49 sec
#  ARIMA(5,0,0)(2,0,1)[12] intercept   : AIC=3777.430, Time=0.66 sec
#  ARIMA(5,0,2)(2,0,1)[12] intercept   : AIC=3770.451, Time=0.65 sec
#  ARIMA(4,0,1)(2,0,1)[12]             : AIC=3784.153, Time=0.58 sec
#
# Best model:  ARIMA(4,0,1)(2,0,1)[12] intercept
# Total fit time: 16.440 seconds

# %% [markdown]
# I graphed my predicted values of firespots with the true values of firespots for 2019 for the Brazilian state of Maranhao below.

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='orange')
plt.plot(x, arima1.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %% [markdown]
# The cell below shows the predicted firespots by month for Maranhao in Brazil for the year 2019.

# %%
arima1.predict(n_periods=test.shape[0])
# Out:
# array([-232.16702717,   86.98962133,  291.6503441 ,  345.55301838,
#         320.60153124,  337.86049363,  401.79804111,  375.76489194,
#         690.58754964,  758.26179739, 1120.48114991, 1134.26913981])

# %% [markdown]
# The predicted total of firespots for Maranhao in Brazil in 2019 was about 5864 (negative values get value of zero).

# %%
arima1.predict(n_periods=test.shape[0]).sum() + 232
# Out:
# 5863.650551323263

# %% [markdown]
# The actual total of firespots for Maranhao in Brazil in 2019 was 3989.

# %%
test.sum()
# Out:
# 3989

# %% [markdown]
# The predicted total of firespots exceeded the actual total of firespots for Maranhao in Brazil in 2019.

# %% [markdown]
# My Maranhao arima model had a pretty low R2 score. My Maranhao model explains little of the variability of the data in comparison to its mean value. 2019 was a year with a lower number of firespots for Maranhao than most other years between 1999-2019, which explains the difficulty in comprehending the variability for the Maranhao data.

# %%
report_metrics(test, arima1.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 340.4582259215768
# RMSE:
# 	 380.5760844367967
# R2:
# 	 0.39848285588975574

# %% [markdown]
# #### Mato Grosso Time Series Exploration

# %% [markdown]
# I procured a Mata Grosso state time series in the next few cells.

# %%
MatoGrossots=firedf.loc[firedf['state']=='MATO GROSSO']

# %%
MatoGrossots=MatoGrossots.set_index('date')['firespots']

# %% [markdown]
# I plotted my Mato Grosso time series to show fire outbreaks per year for the Brazilian state of Mato Grosso between 1999-2019.

# %%
MatoGrossots.plot(color='green', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Mato Grosso", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Mato Grosso')

# %% [markdown]
# Fire outbreaks may vary, but are generally decreasing.

# %% [markdown]
# I designed an arima model to predict firespots for the year 2019 for the state of Mato Grosso in Brazil.

# %%
MatoGrossotsdf=pd.DataFrame(MatoGrossots)

# %%
MatoGrossotsdfar=MatoGrossotsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(MatoGrossotsdfar, test_size=12)

# %%
arima2 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=4443.245, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4590.027, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4482.782, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4508.633, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4588.030, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=4470.912, Time=0.21 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=4448.605, Time=0.17 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=4445.042, Time=0.49 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=4444.471, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=4547.754, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=4470.673, Time=0.45 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=4444.066, Time=0.48 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=4442.691, Time=0.55 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=4440.132, Time=0.55 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=4442.523, Time=0.40 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=4442.736, Time=0.44 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=4440.492, Time=0.17 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=4455.018, Time=0.48 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=4462.654, Time=0.47 sec
#  ARIMA(1,1,3)(2,0,2)[12] intercept   : AIC=4441.400, Time=0.60 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=4474.918, Time=0.41 sec
#  ARIMA(0,1,3)(2,0,2)[12] intercept   : AIC=4439.853, Time=0.56 sec
#  ARIMA(0,1,3)(1,0,2)[12] intercept   : AIC=4441.908, Time=0.49 sec
#  ARIMA(0,1,3)(2,0,1)[12] intercept   : AIC=4442.676, Time=0.45 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=4441.400, Time=0.25 sec
#  ARIMA(0,1,4)(2,0,2)[12] intercept   : AIC=4416.144, Time=0.68 sec
#  ARIMA(0,1,4)(1,0,2)[12] intercept   : AIC=4419.308, Time=0.58 sec
#  ARIMA(0,1,4)(2,0,1)[12] intercept   : AIC=4420.313, Time=0.44 sec
#  ARIMA(0,1,4)(1,0,1)[12] intercept   : AIC=4419.113, Time=0.22 sec
#  ARIMA(1,1,4)(2,0,2)[12] intercept   : AIC=4416.715, Time=0.69 sec
#  ARIMA(0,1,5)(2,0,2)[12] intercept   : AIC=4431.033, Time=0.81 sec
#  ARIMA(1,1,5)(2,0,2)[12] intercept   : AIC=4393.079, Time=0.89 sec
#  ARIMA(1,1,5)(1,0,2)[12] intercept   : AIC=4398.669, Time=0.70 sec
#  ARIMA(1,1,5)(2,0,1)[12] intercept   : AIC=4400.010, Time=0.51 sec
#  ARIMA(1,1,5)(1,0,1)[12] intercept   : AIC=4399.241, Time=0.29 sec
#  ARIMA(2,1,5)(2,0,2)[12] intercept   : AIC=4381.252, Time=0.94 sec
#  ARIMA(2,1,5)(1,0,2)[12] intercept   : AIC=4392.645, Time=0.74 sec
#  ARIMA(2,1,5)(2,0,1)[12] intercept   : AIC=4393.633, Time=0.63 sec
#  ARIMA(2,1,5)(1,0,1)[12] intercept   : AIC=4392.418, Time=0.44 sec
#  ARIMA(2,1,4)(2,0,2)[12] intercept   : AIC=4401.135, Time=0.71 sec
#  ARIMA(3,1,5)(2,0,2)[12] intercept   : AIC=4384.680, Time=0.82 sec
#  ARIMA(3,1,4)(2,0,2)[12] intercept   : AIC=4397.282, Time=0.77 sec
#  ARIMA(2,1,5)(2,0,2)[12]             : AIC=4377.060, Time=0.83 sec
#  ARIMA(2,1,5)(1,0,2)[12]             : AIC=4381.023, Time=0.72 sec
#  ARIMA(2,1,5)(2,0,1)[12]             : AIC=4383.842, Time=0.66 sec
#  ARIMA(2,1,5)(1,0,1)[12]             : AIC=4382.277, Time=0.40 sec
#  ARIMA(1,1,5)(2,0,2)[12]             : AIC=inf, Time=0.76 sec
#  ARIMA(2,1,4)(2,0,2)[12]             : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,5)(2,0,2)[12]             : AIC=4376.712, Time=0.79 sec
#  ARIMA(3,1,5)(1,0,2)[12]             : AIC=4381.757, Time=0.71 sec
#  ARIMA(3,1,5)(2,0,1)[12]             : AIC=4384.810, Time=0.58 sec
#  ARIMA(3,1,5)(1,0,1)[12]             : AIC=4382.617, Time=0.31 sec
#  ARIMA(3,1,4)(2,0,2)[12]             : AIC=4389.408, Time=0.72 sec
#  ARIMA(4,1,5)(2,0,2)[12]             : AIC=4375.168, Time=0.90 sec
#  ARIMA(4,1,5)(1,0,2)[12]             : AIC=4382.332, Time=0.88 sec
#  ARIMA(4,1,5)(2,0,1)[12]             : AIC=4382.676, Time=0.86 sec
#  ARIMA(4,1,5)(1,0,1)[12]             : AIC=inf, Time=0.46 sec
#  ARIMA(4,1,4)(2,0,2)[12]             : AIC=4388.779, Time=0.82 sec
#  ARIMA(5,1,5)(2,0,2)[12]             : AIC=inf, Time=0.92 sec
#  ARIMA(5,1,4)(2,0,2)[12]             : AIC=4376.766, Time=0.84 sec
#  ARIMA(4,1,5)(2,0,2)[12] intercept   : AIC=inf, Time=0.93 sec
#
# Best model:  ARIMA(4,1,5)(2,0,2)[12]
# Total fit time: 33.307 seconds

# %% [markdown]
# I graphed my predicted values of firespots with the true values of firespots for 2019 for the Brazilian state of Mato Grosso below.

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='green')
plt.plot(x, arima2.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %% [markdown]
# The cell below shows the predicted firespots by month for Mato Grosso in Brazil for the year 2019.

# %%
arima2.predict(n_periods=test.shape[0])
# Out:
# array([ 174.47199257,  404.90014812,  675.87270515,  579.04693963,
#         688.05119713, 1164.72716915, 1545.92330672, 2744.05546835,
#        3991.73354213, 1425.55033779,  437.5824358 ,  313.77294992])

# %% [markdown]
# The predicted total of firespots for Mato Grosso in Brazil in 2019 was about 14146.

# %%
arima2.predict(n_periods=test.shape[0]).sum()
# Out:
# 14145.688192452673

# %% [markdown]
# The actual total of firespots for Mato Grosso in Brazil in 2019 was 17479.

# %%
test.sum()
# Out:
# 17479

# %% [markdown]
# The actual total of firespots exceeded the predicted total of firespots for Mato Grosso in Brazil in 2019.

# %% [markdown]
# My Mato Grosso arima model had a pretty high R2 score. My Mato Grosso model explains a lot of the variability of the data in comparison to its mean value.

# %%
report_metrics(test, arima2.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 430.33343915988235
# RMSE:
# 	 784.7266117996926
# R2:
# 	 0.7824596432536743

# %% [markdown]
# #### Para Time Series Exploration

# %% [markdown]
# I procured a Para state time series in the next few cells.

# %%
Parats=firedf.loc[firedf['state']=='PARA']

# %%
Parats=Parats.set_index('date')['firespots']

# %% [markdown]
# I plotted my Para time series to show fire outbreaks per year for the Brazilian state of Para between 1999-2019.

# %%
Parats.plot(color='red', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Para", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Para')

# %% [markdown]
# Fire outbreaks are generally decreasing until about the year 2014. Then fire outbreaks vary.

# %% [markdown]
# I designed an arima model to predict firespots for the year 2019 for the state of Para in Brazil.

# %%
Paratsdf=pd.DataFrame(Parats)

# %%
Paratsdfar=Paratsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Paratsdfar, test_size=12)

# %%
arima3 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=4628.094, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4817.617, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=4638.409, Time=0.17 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=4683.871, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=4909.855, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=4664.732, Time=0.19 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=4643.553, Time=0.29 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=4620.535, Time=0.44 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=4618.840, Time=0.41 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=4618.261, Time=0.37 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=4641.127, Time=0.19 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=4616.910, Time=0.44 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=4624.868, Time=0.18 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=4618.322, Time=0.44 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=4617.933, Time=0.38 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=4644.118, Time=0.43 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=4618.817, Time=0.39 sec
#  ARIMA(1,0,3)(2,0,1)[12] intercept   : AIC=4605.136, Time=0.47 sec
#  ARIMA(1,0,3)(1,0,1)[12] intercept   : AIC=4611.107, Time=0.19 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=4606.937, Time=0.41 sec
#  ARIMA(1,0,3)(2,0,2)[12] intercept   : AIC=4607.740, Time=0.47 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=4629.281, Time=0.18 sec
#  ARIMA(1,0,3)(1,0,2)[12] intercept   : AIC=4605.772, Time=0.41 sec
#  ARIMA(0,0,3)(2,0,1)[12] intercept   : AIC=4612.456, Time=0.36 sec
#  ARIMA(2,0,3)(2,0,1)[12] intercept   : AIC=4605.530, Time=0.54 sec
#  ARIMA(1,0,4)(2,0,1)[12] intercept   : AIC=4599.558, Time=0.48 sec
#  ARIMA(1,0,4)(1,0,1)[12] intercept   : AIC=4602.187, Time=0.23 sec
#  ARIMA(1,0,4)(2,0,0)[12] intercept   : AIC=4607.410, Time=0.49 sec
#  ARIMA(1,0,4)(2,0,2)[12] intercept   : AIC=4601.130, Time=0.61 sec
#  ARIMA(1,0,4)(1,0,0)[12] intercept   : AIC=4631.520, Time=0.18 sec
#  ARIMA(1,0,4)(1,0,2)[12] intercept   : AIC=4599.513, Time=0.56 sec
#  ARIMA(1,0,4)(0,0,2)[12] intercept   : AIC=4640.132, Time=0.48 sec
#  ARIMA(1,0,4)(0,0,1)[12] intercept   : AIC=4658.198, Time=0.26 sec
#  ARIMA(0,0,4)(1,0,2)[12] intercept   : AIC=4642.776, Time=0.52 sec
#  ARIMA(2,0,4)(1,0,2)[12] intercept   : AIC=4588.782, Time=0.65 sec
#  ARIMA(2,0,4)(0,0,2)[12] intercept   : AIC=4632.208, Time=0.53 sec
#  ARIMA(2,0,4)(1,0,1)[12] intercept   : AIC=4592.485, Time=0.25 sec
#  ARIMA(2,0,4)(2,0,2)[12] intercept   : AIC=4590.850, Time=0.64 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=4656.450, Time=0.23 sec
#  ARIMA(2,0,4)(2,0,1)[12] intercept   : AIC=4589.380, Time=0.49 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=4606.179, Time=0.49 sec
#  ARIMA(3,0,4)(1,0,2)[12] intercept   : AIC=4587.091, Time=0.63 sec
#  ARIMA(3,0,4)(0,0,2)[12] intercept   : AIC=4637.751, Time=0.64 sec
#  ARIMA(3,0,4)(1,0,1)[12] intercept   : AIC=4590.537, Time=0.28 sec
#  ARIMA(3,0,4)(2,0,2)[12] intercept   : AIC=4589.299, Time=0.75 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=4659.652, Time=0.25 sec
#  ARIMA(3,0,4)(2,0,1)[12] intercept   : AIC=4588.109, Time=0.63 sec
#  ARIMA(3,0,3)(1,0,2)[12] intercept   : AIC=4626.925, Time=0.51 sec
#  ARIMA(4,0,4)(1,0,2)[12] intercept   : AIC=4588.116, Time=0.67 sec
#  ARIMA(3,0,5)(1,0,2)[12] intercept   : AIC=4588.089, Time=0.71 sec
#  ARIMA(2,0,5)(1,0,2)[12] intercept   : AIC=4671.375, Time=0.69 sec
#  ARIMA(4,0,3)(1,0,2)[12] intercept   : AIC=4603.559, Time=0.61 sec
#  ARIMA(4,0,5)(1,0,2)[12] intercept   : AIC=4599.576, Time=0.91 sec
#  ARIMA(3,0,4)(1,0,2)[12]             : AIC=4587.348, Time=0.62 sec
#
# Best model:  ARIMA(3,0,4)(1,0,2)[12] intercept
# Total fit time: 22.729 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='red')
plt.plot(x, arima3.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima3.predict(n_periods=test.shape[0])
# Out:
# array([ 129.28091029,  503.02788021,  354.68512124, 1058.43659119,
#        1499.70502102, 1601.63879228, 2874.94828625, 5912.7763746 ,
#        8269.47647566, 5543.86122322, 7272.91286827, 3966.76987079])

# %%
arima3.predict(n_periods=test.shape[0]).sum()
# Out:
# 38987.5194150151

# %%
test.sum()
# Out:
# 29700

# %%
report_metrics(test, arima3.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 1543.1315923913846
# RMSE:
# 	 2014.6832866470977
# R2:
# 	 0.610664560966858

# %%
Rondoniats=firedf.loc[firedf['state']=='RONDONIA']

# %%
Rondoniats=Rondoniats.set_index('date')['firespots']

# %%
Rondoniats.plot(color='mediumpurple', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Rondonia", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Rondonia')

# %%
Rondoniatsdf=pd.DataFrame(Rondoniats)

# %%
Rondoniatsdfar=Rondoniatsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Rondoniatsdfar, test_size=12)

# %%
arima4 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=4371.957, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4575.771, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=4386.099, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=4429.831, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=4611.768, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=4427.219, Time=0.16 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=4378.317, Time=0.23 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=4361.978, Time=0.46 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=4360.718, Time=0.45 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=4358.673, Time=0.34 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=4376.379, Time=0.20 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=4360.026, Time=0.38 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=4368.418, Time=0.17 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=4358.638, Time=0.29 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=4375.804, Time=0.15 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=4359.132, Time=0.31 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=4371.264, Time=0.16 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=4366.989, Time=0.25 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=4362.370, Time=0.31 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=4359.746, Time=0.36 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=4361.344, Time=0.43 sec
#  ARIMA(0,0,2)(2,0,0)[12]             : AIC=4364.842, Time=0.15 sec
#
# Best model:  ARIMA(0,0,2)(2,0,0)[12] intercept
# Total fit time: 5.271 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='mediumpurple')
plt.plot(x, arima4.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima4.predict(n_periods=test.shape[0])
# Out:
# array([ 598.86551907,  737.02971291,  814.43261997,  806.5403131 ,
#         821.44272822,  903.24839436, 1429.32758192, 2665.73565767,
#        4534.30761673, 1768.35451811, 1020.20067134,  834.17918957])

# %%
arima4.predict(n_periods=test.shape[0]).sum()
# Out:
# 16933.66452297847

# %%
test.sum()
# Out:
# 11206

# %%
report_metrics(test, arima4.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 965.016100636711
# RMSE:
# 	 1141.6351204086523
# R2:
# 	 0.5545128612361949

# %%
Roraimats=firedf.loc[firedf['state']=='RORAIMA']

# %%
Roraimats=Roraimats.set_index('date')['firespots']

# %%
Roraimats.plot(color='sienna', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Roraima", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Roraima')

# %%
Roraimatsdf=pd.DataFrame(Roraimats)

# %%
Roraimatsdfar=Roraimatsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Roraimatsdfar, test_size=12)

# %%
arima5 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=3270.376, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=3365.103, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=3291.827, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=3316.784, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=3450.150, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=3285.381, Time=0.14 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=3275.831, Time=0.20 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=3262.036, Time=0.47 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=3259.818, Time=0.44 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=3257.660, Time=0.34 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=3273.713, Time=0.15 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=3259.421, Time=0.39 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=3267.543, Time=0.16 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=3259.748, Time=0.28 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=3276.913, Time=0.41 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=3259.159, Time=0.41 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=3297.668, Time=0.24 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=3258.939, Time=0.29 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=3261.449, Time=0.37 sec
#  ARIMA(2,0,3)(2,0,0)[12] intercept   : AIC=3260.871, Time=0.46 sec
#  ARIMA(1,0,2)(2,0,0)[12]             : AIC=3268.638, Time=0.17 sec
#
# Best model:  ARIMA(1,0,2)(2,0,0)[12] intercept
# Total fit time: 5.422 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='sienna')
plt.plot(x, arima5.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima5.predict(n_periods=test.shape[0])
# Out:
# array([180.5945615 , 224.79544049, 319.97099429, 161.82184063,
#        111.44192219, 104.01332837, 103.53027155, 112.49968626,
#        116.4947125 , 172.49486713, 243.68051141, 218.66961689])

# %%
arima5.predict(n_periods=test.shape[0]).sum()
# Out:
# 2070.007753209252

# %%
test.sum()
# Out:
# 4775

# %%
report_metrics(test, arima5.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 389.8868399488369
# RMSE:
# 	 692.1044579483406
# R2:
# 	 0.018389321478993637

# %%
Amapats=firedf.loc[firedf['state']=='AMAPA']

# %%
Amapats=Amapats.set_index('date')['firespots']

# %%
Amapats.plot(color='violet', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Amapa", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Amapa')

# %%
Amapatsdf=pd.DataFrame(Amapats)

# %%
Amapatsdfar=Amapatsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Amapatsdfar, test_size=12)

# %%
arima6 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=3231.916, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=3442.737, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=3252.862, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=3274.856, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=3492.994, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=3268.924, Time=0.13 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=3237.396, Time=0.22 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=3231.025, Time=0.47 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=3229.378, Time=0.43 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=3227.503, Time=0.33 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=3235.412, Time=0.20 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=3228.251, Time=0.38 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=3228.082, Time=0.18 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=3228.056, Time=0.25 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=3229.235, Time=0.32 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=3229.686, Time=0.39 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=3238.345, Time=0.24 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=3231.740, Time=0.28 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=3228.241, Time=0.40 sec
#  ARIMA(2,0,3)(2,0,0)[12] intercept   : AIC=3231.035, Time=0.53 sec
#  ARIMA(1,0,2)(2,0,0)[12]             : AIC=3237.525, Time=0.19 sec
#
# Best model:  ARIMA(1,0,2)(2,0,0)[12] intercept
# Total fit time: 5.436 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='violet')
plt.plot(x, arima6.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima6.predict(n_periods=test.shape[0])
# Out:
# array([-47.23455404,  61.80849466,  61.32130664,  62.56152914,
#         62.28734769,  63.14764914,  63.83443558,  84.91442708,
#        136.95624012, 420.6177509 , 508.24815304, 167.68066646])

# %%
arima6.predict(n_periods=test.shape[0]).sum() + 47
# Out:
# 1693.1434464021102

# %%
test.sum()
# Out:
# 1272

# %%
report_metrics(test, arima6.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 59.78871437053429
# RMSE:
# 	 67.76259247657073
# R2:
# 	 0.872785977518136

# %%
Tocantinsts=firedf.loc[firedf['state']=='TOCANTINS']

# %%
Tocantinsts=Tocantinsts.set_index('date')['firespots']

# %%
Tocantinsts.plot(color='gray', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Tocantins", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Tocantins')

# %%
Tocantinstsdf=pd.DataFrame(Tocantinsts)

# %%
Tocantinstsdfar=Tocantinstsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Tocantinstsdfar, test_size=12)

# %%
arima7 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=2884.598, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=3050.647, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2867.367, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2907.532, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=3090.574, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=2990.797, Time=0.02 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=2862.855, Time=0.51 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=2899.267, Time=0.34 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=2901.764, Time=0.13 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=2966.873, Time=0.30 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=2894.782, Time=0.59 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=2888.580, Time=0.33 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=2889.062, Time=0.22 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=2891.575, Time=0.42 sec
#  ARIMA(1,0,0)(2,0,0)[12]             : AIC=2885.761, Time=0.13 sec
#
# Best model:  ARIMA(1,0,0)(2,0,0)[12] intercept
# Total fit time: 3.442 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='gray')
plt.plot(x, arima7.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima7.predict(n_periods=test.shape[0])
# Out:
# array([ 27.59387452,  32.66127363,  33.37962467,  33.81639993,
#         36.37940367,  49.36795495,  65.74994228,  73.0474528 ,
#        165.25009372,  95.02884595,  71.16868654,  51.84171147])

# %%
arima7.predict(n_periods=test.shape[0]).sum()
# Out:
# 735.2852641334896

# %%
test.sum()
# Out:
# 247

# %%
report_metrics(test, arima7.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 40.6904386777908
# RMSE:
# 	 49.22299609377658
# R2:
# 	 -4.9108218544141495

# %%
Acrets=firedf.loc[firedf['state']=='ACRE']

# %%
Acrets=Acrets.set_index('date')['firespots']

# %%
Acrets.plot(color='y', figsize=(8,5))
plt.xticks(rotation= 90)
plt.xlabel("Year", fontsize= 14)
plt.ylabel("Fire Outbreaks", fontsize= 14)
plt.title("Fire Outbreaks Per Year For Acre", fontsize= 18)
# Out:
# Text(0.5, 1.0, 'Fire Outbreaks Per Year For Acre')

# %%
Acretsdf=pd.DataFrame(Acrets)

# %%
Acretsdfar=Acretsdf['firespots'].asfreq('MS', fill_value=0)

# %%
train, test = model_selection.train_test_split(Acretsdfar, test_size=12)

# %%
arima8 = pm.auto_arima(train, error_action='ignore', trace=True,
                      suppress_warnings=True, maxiter=10,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=3823.731, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=3993.549, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=3841.891, Time=0.17 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=3872.582, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=4029.489, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=3874.937, Time=0.16 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=3832.585, Time=0.25 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=3818.785, Time=0.44 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=3816.407, Time=0.40 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=3814.212, Time=0.40 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=3831.308, Time=0.19 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=3816.340, Time=0.38 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=3821.534, Time=0.17 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=3816.890, Time=0.32 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=3815.825, Time=0.39 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=3818.564, Time=0.39 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=3816.542, Time=0.28 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=3821.484, Time=0.30 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=3816.296, Time=0.36 sec
#  ARIMA(2,0,3)(2,0,0)[12] intercept   : AIC=3816.737, Time=0.42 sec
#  ARIMA(1,0,2)(2,0,0)[12]             : AIC=3824.094, Time=0.18 sec
#
# Best model:  ARIMA(1,0,2)(2,0,0)[12] intercept
# Total fit time: 5.519 seconds

# %%
# Plot actual test vs. forecasts:
plt.figure(figsize=(10,6))
x = np.arange(test.shape[0])
plt.plot(x, test, color='y')
plt.plot(x, arima8.predict(n_periods=test.shape[0]), color= 'black')
plt.xlabel('Test Samples', fontsize= 14)
plt.ylabel('Firespots', fontsize=14)
plt.title('Actual test samples vs. forecasts', fontsize= 20)
plt.legend(labels= ['actual', 'forecasts'])
plt.show()

# %%
arima8.predict(n_periods=test.shape[0])
# Out:
# array([ 178.79459948,  157.46204247,  246.36709009,  181.53930747,
#         236.65390724,  221.85537333,  492.09394758, 1188.02810039,
#        2945.35193198,  867.79117684,  259.36675505,  209.79439198])

# %%
arima8.predict(n_periods=test.shape[0]).sum()
# Out:
# 7185.098623907704

# %%
test.sum()
# Out:
# 6802

# %%
report_metrics(test, arima8.predict(n_periods=test.shape[0]))
# Out:
# MAE:
# 	 347.6948799301911
# RMSE:
# 	 583.6922166081316
# R2:
# 	 0.7184615982047373
